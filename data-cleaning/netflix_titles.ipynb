# %%
# import some packages
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('datasets//netflix_titles.csv')

# %%
# take a glimpse at the data
df.head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s2       December 23, 2016          2016  TV-MA     93 min
# s3       December 20, 2018          2011      R     78 min
# s4       November 16, 2017          2009  PG-13     80 min
# s5         January 1, 2020          2008  PG-13    123 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...

# %%
# let's first start by setting show_id as index
df.set_index('show_id', inplace=True)

# %%
# let's see if there's any incorrect data type
df.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# convert date added to date time
df['date_added'] = pd.to_datetime(df['date_added'], infer_datetime_format=True)

# %%
# rows and column
df.shape
# Out:
# (7787, 11)

# %%
# how many null values in each column
for column in df.columns:
    num_null = df[column].isna().sum()
    print(f'{column}:- {round((num_null/df.shape[0]) * 100)}% COUNT: {num_null}')
# Out:
# type:- 0% COUNT: 0
# title:- 0% COUNT: 0
# director:- 31% COUNT: 2389
# cast:- 9% COUNT: 718
# country:- 7% COUNT: 507
# date_added:- 0% COUNT: 10
# release_year:- 0% COUNT: 0
# rating:- 0% COUNT: 7
# duration:- 0% COUNT: 0
# listed_in:- 0% COUNT: 0
# description:- 0% COUNT: 0

# %%
# set missing values in director column to 'UNKNOWN'
df['director'].fillna('UNKNOWN', inplace=True)

# %%
# drop every row containing missing values
df.dropna(axis=0, inplace=True)

# %%
# add column for the number of cast
df['num_of_cast'] = df['cast'].apply(lambda x: len(x.split(',')))

# %%
# repeat above step for genres
df['num_of_genre'] = df['listed_in'].apply(lambda x: len(x.split(',')))

# %%
# the data is cleaned
df.head()
# Out:
#             type                  title           director  \
# show_id
# s1       TV Show                     3%            UNKNOWN
# s2         Movie                   7:19  Jorge Michel Grau
# s3         Movie                  23:59       Gilbert Chan
# s4         Movie                      9        Shane Acker
# s5         Movie                     21     Robert Luketic
# ...          ...                    ...                ...
# s7781      Movie                    Zoo       Shlok Sharma
# s7782      Movie                   Zoom       Peter Hewitt
# s7783      Movie                   Zozo        Josef Fares
# s7784      Movie                 Zubaan        Mozez Singh
# s7786    TV Show  Zumbo's Just Desserts            UNKNOWN
#
#                                                       cast  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                                                    ...
# s7781    Shashank Arora, Shweta Tripathi, Rahul Kumar, ...
# s7782    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# s7783    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# s7784    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# s7786                           Adriano Zumbo, Rachel Khoo
#
#                                                    country date_added  \
# show_id
# s1                                                  Brazil 2020-08-14
# s2                                                  Mexico 2016-12-23
# s3                                               Singapore 2018-12-20
# s4                                           United States 2017-11-16
# s5                                           United States 2020-01-01
# ...                                                    ...        ...
# s7781                                                India 2018-07-01
# s7782                                        United States 2020-01-11
# s7783    Sweden, Czech Republic, United Kingdom, Denmar... 2020-10-19
# s7784                                                India 2019-03-02
# s7786                                            Australia 2020-10-31
#
#          release_year rating   duration  \
# show_id
# s1               2020  TV-MA  4 Seasons
# s2               2016  TV-MA     93 min
# s3               2011      R     78 min
# s4               2009  PG-13     80 min
# s5               2008  PG-13    123 min
# ...               ...    ...        ...
# s7781            2018  TV-MA     94 min
# s7782            2006     PG     88 min
# s7783            2005  TV-MA     99 min
# s7784            2015  TV-14    111 min
# s7786            2019  TV-PG   1 Season
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
# ...                                                    ...
# s7781     Dramas, Independent Movies, International Movies
# s7782                   Children & Family Movies, Comedies
# s7783                         Dramas, International Movies
# s7784       Dramas, International Movies, Music & Musicals
# s7786                   International TV Shows, Reality TV
#
#                                                description  num_of_cast  \
# show_id
# s1       In a future where the elite inhabit an island ...           11
# s2       After a devastating earthquake hits Mexico Cit...            6
# s3       When an army recruit is found dead, his fellow...            9
# s4       In a postapocalyptic world, rag-doll robots hi...            9
# s5       A brilliant group of students become card-coun...           12
# ...                                                    ...          ...
# s7781    A drug dealer starts having doubts about his t...            6
# s7782    Dragged from civilian life, a former superhero...            9
# s7783    When Lebanon's Civil War deprives Zozo of his ...            7
# s7784    A scrappy but poor boy worms his way into a ty...            8
# s7786    Dessert wizard Adriano Zumbo looks for the nex...            2
#
#          num_of_genre
# show_id
# s1                  3
# s2                  2
# s3                  2
# s4                  3
# s5                  1
# ...               ...
# s7781               3
# s7782               2
# s7783               2
# s7784               3
# s7786               2
#
# [6643 rows x 13 columns]

# %%
# no more missing values
df.isna().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# num_of_cast     0
# num_of_genre    0
# dtype: int64

# %%
df.to_csv('..//EDA//datasets//netflix_titles.csv')
