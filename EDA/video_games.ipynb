# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
# read the data file
df = pd.read_csv('Data Files/cleaned-vg-data')

# %%
df
# Out:
#         Rank                           Name             Genre ESRB_Rating  \
# 0          1                     Wii Sports            Sports           E
# 1          2              Super Mario Bros.          Platform           E
# 2          3                 Mario Kart Wii            Racing           E
# 3          4  PlayerUnknown's Battlegrounds           Shooter           E
# 4          5              Wii Sports Resort            Sports           E
# ...      ...                            ...               ...         ...
# 55754  55788                    Indivisible      Role-Playing           E
# 55755  55789                     Lost Ember         Adventure          RP
# 55756  55790                     Lost Ember         Adventure          RP
# 55757  55791                     Lost Ember         Adventure          RP
# 55758  55792                     Falcon Age  Action-Adventure          RP
#
#       Platform         Publisher         Developer  Global_Sales  Other_Sales  \
# ...

# %%
# the data isn't cleaned. so let's fix that before proceeding
df.isna().sum()
# Out:
# Rank             0
# Name             0
# Genre            0
# ESRB_Rating      0
# Platform         0
# Publisher        0
# Developer        0
# Global_Sales    19
# Other_Sales     19
# Year             0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.title('Most common Genre')
sns.barplot(y=df['Genre'].value_counts().index, x=df['Genre'].value_counts().values)
# Out:
# <AxesSubplot:title={'center':'Most common Genre'}>

# %%
# Game release year
plt.figure(figsize=(16, 9))
plt.ylabel('Number of games released')
plt.xlabel('Year of game release')
years = df['Year'].value_counts()
sns.lineplot(y=years.values, x=years.index)
# Out:
# <AxesSubplot:xlabel='Year of game release', ylabel='Number of games released'>

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Genre', 'ESRB_Rating', 'Platform', 'Publisher',
#        'Developer', 'Global_Sales', 'Other_Sales', 'Year'],
#       dtype='object')

# %%
plt.title('distribution of release year of games')
plt.hist(df.Year);

# %%
plt.title('Distribution of global sales')
plt.hist(df.Global_Sales);

# %%
plt.title('Distribution of other sales')
plt.hist(df.Other_Sales);

# %%
platforms = df.Platform.value_counts()
plt.figure(figsize=(12,6))
plt.title('Which platform has the highest users/number of games')
sns.barplot(y=platforms.index[:11], x=platforms.values[:11])
# Out:
# <AxesSubplot:title={'center':'Which platform has the highest users/number of games'}>

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Genre', 'ESRB_Rating', 'Platform', 'Publisher',
#        'Developer', 'Global_Sales', 'Other_Sales', 'Year'],
#       dtype='object')

# %%
pltf = df.loc[(df.Platform == 'PC')  | (df.Platform == 'PS2')]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Global_Sales', y='Other_Sales', hue='Platform', data=pltf)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Other_Sales'>

# %%
sns.boxplot(x=df.Year);

# %%
plt.figure(figsize=(12,6))
plt.title('Developers')
devs = df['Developer'].value_counts()[:20]
sns.barplot(x=devs.values, y=devs.index)
# Out:
# <AxesSubplot:title={'center':'Developers'}>

# %%
plt.figure(figsize=(12,6))
plt.title('Publishers')
devs = df['Publisher'].value_counts()[:20]
sns.barplot(x=devs.values, y=devs.index)
# Out:
# <AxesSubplot:title={'center':'Publishers'}>
